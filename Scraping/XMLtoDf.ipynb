# %%
import requests

user_agent_url = 'http://www.user-agents.org/allagents.xml'
xml_data = requests.get(user_agent_url).content

# %%
import xml.etree.ElementTree as ET
import pandas as pd

class XML2DataFrame:

    def __init__(self, xml_data):
        self.root = ET.XML(xml_data)

    def parse_root(self, root):
        '''Return a list of dictionaries from the text
         and attributes of the children under this XML root.'''
        return [self.parse_element(child) for child in iter(root)]

    def parse_element(self, element, parsed=None):
        ''' Collect {key:attribute} and {tag:text} from thie XML
         element and all its children into a single dictionary of strings.'''
        if parsed is None:
            parsed = dict()

        for key in element.keys():
            if key not in parsed:
                parsed[key] = element.attrib.get(key)
            else:
                raise ValueError('duplicate attribute {0} at element {1}'.format(key, element.getroottree().getpath(element))           

        for child in list(element):
            self.parse_element(child, parsed)

        return parsed

    def process_data(self):
        ''' Initiate the root XML, parse it, and return a dataframe'''
        structure_data = self.parse_root(self.root)
        return pd.DataFrame(structure_data)

xml2df = XML2DataFrame(xml_data)
xml_dataframe = xml2df.process_data()
# Out:
#   File "<ipython-input-5-da00f8aa3fce>", line 26
#     for child in list(element):
#                               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io

def iter_docs(author):
    author_attr = author.attrib
    for doc in author.iter('document'):
        doc_dict = author_attr.copy()
        doc_dict.update(doc.attrib)
        doc_dict['data'] = doc.text
        yield doc_dict

xml_data = io.StringIO('''\
<?xml version="1.0" encoding="UTF-8"?>
<user-agents>
<user-agent>
<ID>id_a_f_3</ID>
<String>!Susie (http://www.sync2it.com/susie)</String>
<Description>Sync2It bookmark management &amp; clustering engine</Description>
<Type>C R</Type>
<Comment/>
<Link1>http://www.sync2it.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_6</ID>
<String>&lt;a href='http://www.unchaos.com/'&gt; UnChaos &lt;/a&gt; From Chaos To Order Hybrid Web Search Engine.(vadim_gonchar@unchaos.com)</String>
<Description>UnCHAOS search robot</Description>
<Type>R</Type>
<Comment>Site is dead</Comment>
<Link1>http://www.unchaos.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_7</ID>
<String>&lt;a href='http://www.unchaos.com/'&gt; UnChaos Bot Hybrid Web Search Engine. &lt;/a&gt; (vadim_gonchar@unchaos.com)</String>
<Description>UnCHAOS search robot</Description>
<Type>R</Type>
<Comment>Site is dead</Comment>
<Link1>http://www.unchaos.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_8</ID>
<String>&lt;b&gt; UnChaosBot From Chaos To Order UnChaos Hybrid Web Search Engine at www.unchaos.com &lt;/b&gt; (info@unchaos.com)</String>
<Description>UnCHAOS search robot</Description>
<Type>R</Type>
<Comment>Site is dead</Comment>
<Link1>http://www.unchaos.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_9</ID>
<String>&lt;http://www.sygol.com/&gt; http://www.sygol.com</String>
<Description>Sygol Search (Italy) robot</Description>
<Type>R</Type>
<Comment>s.also SygolBot</Comment>
<Link1>http://www.sygol.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_4</ID>
<String>( Robots.txt Validator http://www.searchengineworld.com/cgi-bin/robotcheck.cgi )</String>
<Description>SearchEngineWorld's robots.txt validator</Description>
<Type>C</Type>
<Comment>Services is no more available</Comment>
<Link1>http://www.searchengineworld.com/cgi-bin/robotcheck.cgi</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_171105_1</ID>
<String>(DreamPassport/3.0; isao/MyDiGiRabi)</String>
<Description>DreamCast DreamPassport browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.dricas.com/dp/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_290606_1</ID>
<String>(Privoxy/1.0)</String>
<Description>Privoxy web proxy</Description>
<Type>P</Type>
<Comment>s.also Privoxy/3.0 (Anonymous)</Comment>
<Link1>http://www.privoxy.org/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_230507_1</ID>
<String>*/Nutch-0.9-dev</String>
<Description>Unknown Yahoo robot</Description>
<Type>R</Type>
<Comment>123.113.184.2xx</Comment>
<Link1>http://www.yahoo.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_5</ID>
<String>+SitiDi.net/SitiDiBot/1.0 (+Have Good Day)</String>
<Description>SitiDi.net search (Germany) robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.sitidi.net/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_1</ID>
<String>-DIE-KRAEHE- META-SEARCH-ENGINE/1.1 http://www.die-kraehe.de</String>
<Description>Die Kraehe Meta-Search-Engine (Germany) link checking</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.die-kraehe.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_060206_1</ID>
<String>123spider-Bot (Version: 1.02, powered by www.123spider.de</String>
<Description>123spider.de (Germany) web directory link checking</Description>
<Type>C</Type>
<Comment/>
<Link1>http://www.123spider.de/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_180806_1</ID>
<String>192.comAgent</String>
<Description>192.com - UK web directory</Description>
<Type>R</Type>
<Comment>217.160.75.2xx</Comment>
<Link1>http://www.192.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_060606_1</ID>
<String>1st ZipCommander (Net) - http://www.zipcommander.com/</String>
<Description>1st ZipCommander Net - IE based browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.zipcommander.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_10</ID>
<String>2Bone_LinkChecker/1.0 libwww-perl/5.64</String>
<Description>2Bone online link checker</Description>
<Type>C</Type>
<Comment/>
<Link1>http://www.2bone.com/links/linkchecker.shtml</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_11</ID>
<String>4anything.com LinkChecker v2.0</String>
<Description>4Anything robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.4anything.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_110207_1</ID>
<String>8484 Boston Project v 1.0</String>
<Description>Unknown guestbook spamming or harvesting tool from diff. IPs</Description>
<Type>S</Type>
<Comment>s. various honey pot sites</Comment>
<Link1>http://www.projecthoneypot.org/bsh_X19tb2RlPWdsb2JhbCZfX2J5PWMmY3RyeT11cyZ1YWc9ODQ4NCtCb3N0b24rUHJvamVjdCt2KzEuMA..</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_2</ID>
<String>:robot/1.0 (linux) ( admin e-mail: undefined http://www.neofonie.de/loesungen/search/robot.html )</String>
<Description>neofonie search robot Germany</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.neofonie.de/loesungen/search/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_12</ID>
<String>A-Online Search</String>
<Description>A-Online.at robot - now Jet2Web Search</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.jet2web.net/portal</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_090707_1</ID>
<String>A1 Keyword Research/1.0.2 (+http://www.micro-sys.dk/products/keyword-research/) miggibot/2007.03.27</String>
<Description>A1 Keyword Research - search engine and keyword optimization software</Description>
<Type>C</Type>
<Comment/>
<Link1>http://www.micro-sys.dk/products/keyword-research/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_100906_1</ID>
<String>A1 Sitemap Generator/1.0 (+http://www.micro-sys.dk/products/sitemap-generator/) miggibot/2006.01.24</String>
<Description>MiggiBot website crawler engine - A1 Sitemap Generator</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.micro-sys.dk/products/sitemap-generator/</Link1>
<Link2>http://www.micro-sys.dk/developer/miggibot/</Link2>
</user-agent>
<user-agent>
<ID>id_a_f_250408_2</ID>
<String>aardvark-crawler</String>
<Description>Aardvark web crawler for Sun's Blog recommendations</Description>
<Type>R</Type>
<Comment>192.9.71.7x</Comment>
<Link1>http://blogs.sun.com/plamere/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_13</ID>
<String>AbachoBOT</String>
<Description>Abacho / Crawler.de robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.abacho.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_14</ID>
<String>AbachoBOT (Mozilla compatible)</String>
<Description>Abacho / Crawler.de robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.abacho.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_15</ID>
<String>ABCdatos BotLink/5.xx.xxx#BBL</String>
<Description>ABCdatos - Castilian program &amp; tutorial directory</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.abcdatos.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_16</ID>
<String>Aberja Checkomat</String>
<Description>Aberja Hybridsuchmaschine (Germany) link checking</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aberja.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_17</ID>
<String>abot/0.1 (abot; http://www.abot.com; abot@abot.com)</String>
<Description>Nameprotect copyright search robot (24.177.134.x)</Description>
<Type>R</Type>
<Comment>s. also - np/0.1_(np;_http://www.nameprotect.com... - aipbot/1.0 (aipbot; http://www.aipbot.com...</Comment>
<Link1>http://www.nameprotect.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_18</ID>
<String>About/0.1libwww-perl/5.47</String>
<Description>About robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.about.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_051206_3</ID>
<String>Accelatech RSSCrawler/0.4</String>
<Description>Accela Technology RSS feed crawler</Description>
<Type>R</Type>
<Comment>125.100.242.2xx</Comment>
<Link1>http://www.accelatech.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_19</ID>
<String>accoona</String>
<Description>Accoona Search robot</Description>
<Type>R</Type>
<Comment>65.17.255.xx</Comment>
<Link1>http://www.accoona.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_20</ID>
<String>Accoona-AI-Agent/1.1.1 (crawler at accoona dot com)</String>
<Description>Accoona Search robot</Description>
<Type>R</Type>
<Comment>65.17.255.xx</Comment>
<Link1>http://www.accoona.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_140906_3</ID>
<String>Accoona-AI-Agent/1.1.2 (aicrawler at accoonabot dot com)</String>
<Description>Accoona Search robot</Description>
<Type>R</Type>
<Comment>65.17.255.xx</Comment>
<Link1>http://www.accoona.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_21</ID>
<String>Ace Explorer</String>
<Description>Ace Explorer - IE based browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.aceexplorer.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_280806_1</ID>
<String>Ack (http://www.ackerm.com/)</String>
<Description>Ackerm search robot</Description>
<Type>R</Type>
<Comment>64.74.153.xx</Comment>
<Link1>http://www.ackerm.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_22</ID>
<String>AcoiRobot</String>
<Description>Acoi picture finder robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://monetdb.cwi.nl/acoi/projects.html</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_23</ID>
<String>Acoon Robot v1.50.001</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.153.10x</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_24</ID>
<String>Acoon Robot v1.52 (http://www.acoon.de)</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.153.10x</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_100508_1</ID>
<String>Acoon-Robot 4.0.x.[xx] (http://www.acoon.de)</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.209.xx</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_010108_1</ID>
<String>Acoon-Robot v3.xx (http://www.acoon.de and http://www.acoon.com)</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.153.10x</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_110507_1</ID>
<String>Acorn/Nutch-0.9 (Non-Profit Search Engine; acorn.isara.org; acorn at isara dot org)</String>
<Description>Acorn Search Project</Description>
<Type>R</Type>
<Comment>124.157.145.1xx</Comment>
<Link1>http://acorn.no-ip.org/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_25</ID>
<String>ActiveBookmark 1.x</String>
<Description>LibMaster.com Active Bookmark HTML page creator</Description>
<Type>C B</Type>
<Comment/>
<Link1>http://www.libmaster.com/software.php</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_060806_2</ID>
<String>Activeworlds</String>
<Description>Activeworlds 3D homepage browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.activeworlds.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_26</ID>
<String>ActiveWorlds/3.xx (xxx)</String>
<Description>Activeworlds 3D homepage browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.activeworlds.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_27</ID>
<String>Ad Muncher v4.xx.x</String>
<Description>Ad Muncher - banner killer</Description>
<Type>P</Type>
<Comment/>
<Link1>http://www.admuncher.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_28</ID>
<String>Ad Muncher v4x Build xxxxx</String>
<Description>Ad Muncher - banner killer</Description>
<Type>P</Type>
<Comment/>
<Link1>http://www.admuncher.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_061006_1</ID>
<String>Adaxas Spider (http://www.adaxas.net/)</String>
<Description>website directory adaxas link checking</Description>
<Type>C</Type>
<Comment>85.10.199.xx</Comment>
<Link1>http://www.adaxas.net/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_29</ID>
<String>Advanced Browser (http://www.avantbrowser.com)</String>
<Description>Avant Browser - IE based browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.avantbrowser.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_30</ID>
<String>AESOP_com_SpiderMan</String>
<Description>Aesop robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aesop.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_31</ID>
<String>agadine/1.x.x (+http://www.agada.de)</String>
<Description>Agada search (Germany) robot</Description>
<Type>R</Type>
<Comment>s. also Mozilla/4.0 (agadine3.0)</Comment>
<Link1>http://www.agada.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_32</ID>
<String>Agent-SharewarePlazaFileCheckBot/2.0+(+http://www.SharewarePlaza.com)</String>
<Description>SharewarePlaza link checking</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.sharewareplaza.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_33</ID>
<String>AgentName/0.1 libwww-perl/5.48</String>
<Description>Linkomatic submission verifier</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.linkomatic.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_34</ID>
<String>AIBOT/2.1 By +(www.21seek.com A Real artificial intelligence search engine China)</String>
<Description>21seek.com (China) robot (218.17.90.xxx)</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.21seek.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_130807_1</ID>
<String>AideRSS/1.0 (aiderss.com)</String>
<Description>AideRss - Postrank RSS and Blog filtering</Description>
<Type>C</Type>
<Comment>72.44.35.2xx</Comment>
<Link1>http://www.aiderss.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_35</ID>
<String>aipbot/1.0 (aipbot; http://www.aipbot.com; aipbot@aipbot.com)</String>
<Description>Nameprotect copyright search robot (24.177.134.x)</Description>
<Type>R</Type>
<Comment>s. also - np/0.1_(np;_http://www.nameprotect.com... - abot/0.1 (abot; http://www.abot.com...</Comment>
<Link1>http://www.nameprotect.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_36</ID>
<String>aipbot/2-beta (aipbot dev; http://aipbot.com; aipbot@aipbot.com)</String>
<Description>Nameprotect copyright search robot (24.177.134.x)</Description>
<Type>R</Type>
<Comment>s. also - np/0.1_(np;_http://www.nameprotect.com... - abot/0.1 (abot; http://www.abot.com...</Comment>
<Link1>http://www.nameprotect.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_291108_1</ID>
<String>Akregator/1.2.9; librss/remnants</String>
<Description>Akregator news feed reader for KDE</Description>
<Type>B</Type>
<Comment/>
<Link1>http://akregator.kde.org/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_37</ID>
<String>Aladin/3.324</String>
<Description>Aladin robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aladin.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_180408_1</ID>
<String>Alcatel-BG3/1.0 UP.Browser/5.0.3.1.2</String>
<Description>Phone.com UP.Browser for mobiles on Alcatel cellphone</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.openwave.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_38</ID>
<String>Aleksika Spider/1.0 (+http://www.aleksika.com/)</String>
<Description>Aleksika Danmark - Search engine optimization spider</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aleksika.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_291108_2</ID>
<String>AlertInfo 2.0 (Powered by Newsbrain)</String>
<Description>Alertinfo - French version of Feedreader 3.xx </Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.feedreader.com/</Link1>
<Link2>http://www.geste.fr/alertinfo/home.html</Link2>
</user-agent>
<user-agent>
<ID>id_a_f_39</ID>
<String>AlkalineBOT/1.3</String>
<Description>Vestris robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://alkaline.vestris.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_40</ID>
<String>AlkalineBOT/1.4 (1.4.0326.0 RTM)</String>
<Description>Vestris robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://alkaline.vestris.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_41</ID>
<String>Allesklar/0.1 libwww-perl/5.46</String>
<Description>Allesklar.de robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.allesklar.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_42</ID>
<String>Alligator 1.31 (www.nearsoftware.com)</String>
<Description>Alligator download manager</Description>
<Type>D</Type>
<Comment/>
<Link1>http://www.nearsoftware.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_011108_1</ID>
<String>Allrati/1.1 (+)</String>
<Description>Unknown robot from Allrati.com</Description>
<Type>R</Type>
<Comment>67.205.96.xxx/67.205.104.xx</Comment>
<Link1>http://www.allrati.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_43</ID>
<String>AltaVista Intranet V2.0 AVS EVAL search@freeit.com</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_44</ID>
<String>AltaVista Intranet V2.0 Compaq Altavista Eval sveand@altavista.net</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_45</ID>
<String>AltaVista Intranet V2.0 evreka.com crawler@evreka.com</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_46</ID>
<String>AltaVista V2.0B crawler@evreka.com</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_280209_1</ID>
<String>amaya/x.xx libwww/x.x.x</String>
<Description>Amaya - W3C's Editor/Browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.w3.org/Amaya/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_47</ID>
<String>AmfibiBOT</String>
<Description>Amfibi Search robot</Description>
<Type>R</Type>
<Comment>64.111.217.9x</Comment>
<Link1>http://www.amfibi.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_48</ID>
<String>Amfibibot/0.06 (Amfibi Web Search; http://www.amfibi.com; agent@amfibi.com)</String>
<Description>Amfibi Search robot</Description>
<Type>R</Type>
<Comment>64.111.217.9x</Comment>
<Link1>http://www.amfibi.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_141105_2</ID>
<String>Amfibibot/0.07 (Amfibi Robot; http://www.amfibi.com; agent@amfibi.com)</String>
<Description>Amfibi Search robot</Description>
<Type>R</Type>
<Comment>64.111.217.9x</Comment>
<Link1>http://www.amfibi.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_49</ID>
<String>amibot</String>
<Description>amibot - Amidalla search engine robot (62.241.33.xx)</Description>
<Type>R</Type>
<Comment>s. also libwww-perl/5.65</Comment>
<Link1>http://www.amidalla.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_50</ID>
<String>Amiga-AWeb/3.4.167SE</String>
<Description>AWeb Amiga browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.amitrix.com/aweb.html</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_51</ID>
<String>AmigaVoyager/3.4.4 (MorphOS/PPC native)</String>
<Description>Voyager - Amiga browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.vapor.com/voyager/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_091205_1</ID>
<String>AmiTCP Miami (AmigaOS 2.04)</String>
<Description>Amiga Miami TCP Stack</Description>
<Type/>
<Comment/>
<Link1>http://home.ptd.net/~strdustr/amirc/Netware.html</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_210608_1</ID>
<String>Amoi 8512/R21.0 NF-Browser/3.3</String>
<Description>NF embedded browser on Amois Skypephone</Description>
<Type>B</Type>
<Comment/>
<Link1>http://3skypephone.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_190206_3</ID>
<String>amzn_assoc</String>
<Description>Amazon.com robot for checking their affiliate sites</Description>
<Type>C</Type>
<Comment>s. also aranhabot</Comment>
<Link1/>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_52</ID>
<String>AnnoMille spider 0.1 alpha - http://www.annomille.it</String>
<Description>Annomille Italian historical oriented robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.annomille.it</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_53</ID>
<String>annotate_google; http://ponderer.org/download/annotate_google.user.js</String>
<Description>annotate Google - Firefox extension for annotating Google search results</Description>
<Type>B</Type>
<Comment/>
<Link1>http://ponderer.org/annotate_google</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_54</ID>
<String>Anonymized by ProxyOS: http://www.megaproxy.com</String>
<Description>Megaproxy user</Description>
<Type>P</Type>
<Comment/>
<Link1>http://www.megaproxy.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_55</ID>
<String>Anonymizer/1.1</String>
<Description>faked user agent</Description>
<Type/>
<Comment/>
<Link1/>
<Link2/>
</user-agent>
</user-agents>
''')

etree = ET.parse(xml_data) #create an ElementTree object 
doc_df = pd.DataFrame(list(iter_docs(etree.getroot())))

# %%
doc_df
# Out:
#                                 KEY  \
# 0  e95a9a6c790ecb95e46cf15bee517651
# 1  bc360cfbafc39970587547215162f0db
# 2  19e71144c50a8b9160b3f0955e906fce
# 3  21d4af9021a174f61b884606c74d9e42
# 4  28a45eb2460899763d709ca00ddbb665
# 5  a0c0712a6a351f85d9f5757e9fff8946
# 6  626726ba8d34d15d02b6d043c55fe691
# 7  2cb473e0f102e2e4a40aa3006e412ae4
#
#                                                 data feature gender language  \
# 0  A large text with lots of strings and punctuat...      xx     xx       EN
# 1  A large text with lots of strings and punctuat...      xx     xx       EN
# 2  A large text with lots of strings and punctuat...      xx     xx       EN
# 3  A large text with lots of strings and punctuat...      xx     xx       EN
# 4  A large text with lots of strings and punctuat...      xx     xx       EN
# 5  A large text with lots of strings and punctuat...      xx     xx       EN
# 6  A large text with lots of strings and punctuat...      xx     xx       EN
# 7  A large text with lots of strings and punctuat...      xx     xx       EN
#
#   type                      web
# 0  XXX  www.foo_bar_exmaple.com
# 1  XXX  www.foo_bar_exmaple.com
# 2  XXX  www.foo_bar_exmaple.com
# 3  XXX  www.foo_bar_exmaple.com
# 4  XXX  www.foo_bar_exmaple.com
# 5  XXX  www.foo_bar_exmaple.com
# 6  XXX  www.foo_bar_exmaple.com
# 7  XXX  www.foo_bar_exmaple.com

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io

def iter_docs(author):
    author_attr = author.attrib
    for doc in author.iter('document'):
        doc_dict = author_attr.copy()
        doc_dict.update(doc.attrib)
        doc_dict['data'] = doc.text
        yield doc_dict

xml_data = io.StringIO('''\
<?xml version="1.0" encoding="UTF-8"?>
<user-agents>
<user-agent>
<ID>id_a_f_3</ID>
<String>!Susie (http://www.sync2it.com/susie)</String>
<Description>Sync2It bookmark management &amp; clustering engine</Description>
<Type>C R</Type>
<Comment/>
<Link1>http://www.sync2it.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_6</ID>
<String>&lt;a href='http://www.unchaos.com/'&gt; UnChaos &lt;/a&gt; From Chaos To Order Hybrid Web Search Engine.(vadim_gonchar@unchaos.com)</String>
<Description>UnCHAOS search robot</Description>
<Type>R</Type>
<Comment>Site is dead</Comment>
<Link1>http://www.unchaos.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_7</ID>
<String>&lt;a href='http://www.unchaos.com/'&gt; UnChaos Bot Hybrid Web Search Engine. &lt;/a&gt; (vadim_gonchar@unchaos.com)</String>
<Description>UnCHAOS search robot</Description>
<Type>R</Type>
<Comment>Site is dead</Comment>
<Link1>http://www.unchaos.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_8</ID>
<String>&lt;b&gt; UnChaosBot From Chaos To Order UnChaos Hybrid Web Search Engine at www.unchaos.com &lt;/b&gt; (info@unchaos.com)</String>
<Description>UnCHAOS search robot</Description>
<Type>R</Type>
<Comment>Site is dead</Comment>
<Link1>http://www.unchaos.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_9</ID>
<String>&lt;http://www.sygol.com/&gt; http://www.sygol.com</String>
<Description>Sygol Search (Italy) robot</Description>
<Type>R</Type>
<Comment>s.also SygolBot</Comment>
<Link1>http://www.sygol.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_4</ID>
<String>( Robots.txt Validator http://www.searchengineworld.com/cgi-bin/robotcheck.cgi )</String>
<Description>SearchEngineWorld's robots.txt validator</Description>
<Type>C</Type>
<Comment>Services is no more available</Comment>
<Link1>http://www.searchengineworld.com/cgi-bin/robotcheck.cgi</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_171105_1</ID>
<String>(DreamPassport/3.0; isao/MyDiGiRabi)</String>
<Description>DreamCast DreamPassport browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.dricas.com/dp/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_290606_1</ID>
<String>(Privoxy/1.0)</String>
<Description>Privoxy web proxy</Description>
<Type>P</Type>
<Comment>s.also Privoxy/3.0 (Anonymous)</Comment>
<Link1>http://www.privoxy.org/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_230507_1</ID>
<String>*/Nutch-0.9-dev</String>
<Description>Unknown Yahoo robot</Description>
<Type>R</Type>
<Comment>123.113.184.2xx</Comment>
<Link1>http://www.yahoo.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_5</ID>
<String>+SitiDi.net/SitiDiBot/1.0 (+Have Good Day)</String>
<Description>SitiDi.net search (Germany) robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.sitidi.net/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_1</ID>
<String>-DIE-KRAEHE- META-SEARCH-ENGINE/1.1 http://www.die-kraehe.de</String>
<Description>Die Kraehe Meta-Search-Engine (Germany) link checking</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.die-kraehe.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_060206_1</ID>
<String>123spider-Bot (Version: 1.02, powered by www.123spider.de</String>
<Description>123spider.de (Germany) web directory link checking</Description>
<Type>C</Type>
<Comment/>
<Link1>http://www.123spider.de/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_180806_1</ID>
<String>192.comAgent</String>
<Description>192.com - UK web directory</Description>
<Type>R</Type>
<Comment>217.160.75.2xx</Comment>
<Link1>http://www.192.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_060606_1</ID>
<String>1st ZipCommander (Net) - http://www.zipcommander.com/</String>
<Description>1st ZipCommander Net - IE based browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.zipcommander.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_10</ID>
<String>2Bone_LinkChecker/1.0 libwww-perl/5.64</String>
<Description>2Bone online link checker</Description>
<Type>C</Type>
<Comment/>
<Link1>http://www.2bone.com/links/linkchecker.shtml</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_11</ID>
<String>4anything.com LinkChecker v2.0</String>
<Description>4Anything robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.4anything.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_110207_1</ID>
<String>8484 Boston Project v 1.0</String>
<Description>Unknown guestbook spamming or harvesting tool from diff. IPs</Description>
<Type>S</Type>
<Comment>s. various honey pot sites</Comment>
<Link1>http://www.projecthoneypot.org/bsh_X19tb2RlPWdsb2JhbCZfX2J5PWMmY3RyeT11cyZ1YWc9ODQ4NCtCb3N0b24rUHJvamVjdCt2KzEuMA..</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_2</ID>
<String>:robot/1.0 (linux) ( admin e-mail: undefined http://www.neofonie.de/loesungen/search/robot.html )</String>
<Description>neofonie search robot Germany</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.neofonie.de/loesungen/search/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_12</ID>
<String>A-Online Search</String>
<Description>A-Online.at robot - now Jet2Web Search</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.jet2web.net/portal</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_090707_1</ID>
<String>A1 Keyword Research/1.0.2 (+http://www.micro-sys.dk/products/keyword-research/) miggibot/2007.03.27</String>
<Description>A1 Keyword Research - search engine and keyword optimization software</Description>
<Type>C</Type>
<Comment/>
<Link1>http://www.micro-sys.dk/products/keyword-research/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_100906_1</ID>
<String>A1 Sitemap Generator/1.0 (+http://www.micro-sys.dk/products/sitemap-generator/) miggibot/2006.01.24</String>
<Description>MiggiBot website crawler engine - A1 Sitemap Generator</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.micro-sys.dk/products/sitemap-generator/</Link1>
<Link2>http://www.micro-sys.dk/developer/miggibot/</Link2>
</user-agent>
<user-agent>
<ID>id_a_f_250408_2</ID>
<String>aardvark-crawler</String>
<Description>Aardvark web crawler for Sun's Blog recommendations</Description>
<Type>R</Type>
<Comment>192.9.71.7x</Comment>
<Link1>http://blogs.sun.com/plamere/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_13</ID>
<String>AbachoBOT</String>
<Description>Abacho / Crawler.de robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.abacho.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_14</ID>
<String>AbachoBOT (Mozilla compatible)</String>
<Description>Abacho / Crawler.de robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.abacho.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_15</ID>
<String>ABCdatos BotLink/5.xx.xxx#BBL</String>
<Description>ABCdatos - Castilian program &amp; tutorial directory</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.abcdatos.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_16</ID>
<String>Aberja Checkomat</String>
<Description>Aberja Hybridsuchmaschine (Germany) link checking</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aberja.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_17</ID>
<String>abot/0.1 (abot; http://www.abot.com; abot@abot.com)</String>
<Description>Nameprotect copyright search robot (24.177.134.x)</Description>
<Type>R</Type>
<Comment>s. also - np/0.1_(np;_http://www.nameprotect.com... - aipbot/1.0 (aipbot; http://www.aipbot.com...</Comment>
<Link1>http://www.nameprotect.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_18</ID>
<String>About/0.1libwww-perl/5.47</String>
<Description>About robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.about.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_051206_3</ID>
<String>Accelatech RSSCrawler/0.4</String>
<Description>Accela Technology RSS feed crawler</Description>
<Type>R</Type>
<Comment>125.100.242.2xx</Comment>
<Link1>http://www.accelatech.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_19</ID>
<String>accoona</String>
<Description>Accoona Search robot</Description>
<Type>R</Type>
<Comment>65.17.255.xx</Comment>
<Link1>http://www.accoona.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_20</ID>
<String>Accoona-AI-Agent/1.1.1 (crawler at accoona dot com)</String>
<Description>Accoona Search robot</Description>
<Type>R</Type>
<Comment>65.17.255.xx</Comment>
<Link1>http://www.accoona.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_140906_3</ID>
<String>Accoona-AI-Agent/1.1.2 (aicrawler at accoonabot dot com)</String>
<Description>Accoona Search robot</Description>
<Type>R</Type>
<Comment>65.17.255.xx</Comment>
<Link1>http://www.accoona.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_21</ID>
<String>Ace Explorer</String>
<Description>Ace Explorer - IE based browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.aceexplorer.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_280806_1</ID>
<String>Ack (http://www.ackerm.com/)</String>
<Description>Ackerm search robot</Description>
<Type>R</Type>
<Comment>64.74.153.xx</Comment>
<Link1>http://www.ackerm.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_22</ID>
<String>AcoiRobot</String>
<Description>Acoi picture finder robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://monetdb.cwi.nl/acoi/projects.html</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_23</ID>
<String>Acoon Robot v1.50.001</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.153.10x</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_24</ID>
<String>Acoon Robot v1.52 (http://www.acoon.de)</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.153.10x</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_100508_1</ID>
<String>Acoon-Robot 4.0.x.[xx] (http://www.acoon.de)</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.209.xx</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_010108_1</ID>
<String>Acoon-Robot v3.xx (http://www.acoon.de and http://www.acoon.com)</String>
<Description>Acoon.de search (Germany) robot</Description>
<Type>R</Type>
<Comment>80.237.153.10x</Comment>
<Link1>http://www.acoon.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_110507_1</ID>
<String>Acorn/Nutch-0.9 (Non-Profit Search Engine; acorn.isara.org; acorn at isara dot org)</String>
<Description>Acorn Search Project</Description>
<Type>R</Type>
<Comment>124.157.145.1xx</Comment>
<Link1>http://acorn.no-ip.org/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_25</ID>
<String>ActiveBookmark 1.x</String>
<Description>LibMaster.com Active Bookmark HTML page creator</Description>
<Type>C B</Type>
<Comment/>
<Link1>http://www.libmaster.com/software.php</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_060806_2</ID>
<String>Activeworlds</String>
<Description>Activeworlds 3D homepage browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.activeworlds.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_26</ID>
<String>ActiveWorlds/3.xx (xxx)</String>
<Description>Activeworlds 3D homepage browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.activeworlds.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_27</ID>
<String>Ad Muncher v4.xx.x</String>
<Description>Ad Muncher - banner killer</Description>
<Type>P</Type>
<Comment/>
<Link1>http://www.admuncher.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_28</ID>
<String>Ad Muncher v4x Build xxxxx</String>
<Description>Ad Muncher - banner killer</Description>
<Type>P</Type>
<Comment/>
<Link1>http://www.admuncher.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_061006_1</ID>
<String>Adaxas Spider (http://www.adaxas.net/)</String>
<Description>website directory adaxas link checking</Description>
<Type>C</Type>
<Comment>85.10.199.xx</Comment>
<Link1>http://www.adaxas.net/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_29</ID>
<String>Advanced Browser (http://www.avantbrowser.com)</String>
<Description>Avant Browser - IE based browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.avantbrowser.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_30</ID>
<String>AESOP_com_SpiderMan</String>
<Description>Aesop robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aesop.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_31</ID>
<String>agadine/1.x.x (+http://www.agada.de)</String>
<Description>Agada search (Germany) robot</Description>
<Type>R</Type>
<Comment>s. also Mozilla/4.0 (agadine3.0)</Comment>
<Link1>http://www.agada.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_32</ID>
<String>Agent-SharewarePlazaFileCheckBot/2.0+(+http://www.SharewarePlaza.com)</String>
<Description>SharewarePlaza link checking</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.sharewareplaza.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_33</ID>
<String>AgentName/0.1 libwww-perl/5.48</String>
<Description>Linkomatic submission verifier</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.linkomatic.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_34</ID>
<String>AIBOT/2.1 By +(www.21seek.com A Real artificial intelligence search engine China)</String>
<Description>21seek.com (China) robot (218.17.90.xxx)</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.21seek.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_130807_1</ID>
<String>AideRSS/1.0 (aiderss.com)</String>
<Description>AideRss - Postrank RSS and Blog filtering</Description>
<Type>C</Type>
<Comment>72.44.35.2xx</Comment>
<Link1>http://www.aiderss.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_35</ID>
<String>aipbot/1.0 (aipbot; http://www.aipbot.com; aipbot@aipbot.com)</String>
<Description>Nameprotect copyright search robot (24.177.134.x)</Description>
<Type>R</Type>
<Comment>s. also - np/0.1_(np;_http://www.nameprotect.com... - abot/0.1 (abot; http://www.abot.com...</Comment>
<Link1>http://www.nameprotect.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_36</ID>
<String>aipbot/2-beta (aipbot dev; http://aipbot.com; aipbot@aipbot.com)</String>
<Description>Nameprotect copyright search robot (24.177.134.x)</Description>
<Type>R</Type>
<Comment>s. also - np/0.1_(np;_http://www.nameprotect.com... - abot/0.1 (abot; http://www.abot.com...</Comment>
<Link1>http://www.nameprotect.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_291108_1</ID>
<String>Akregator/1.2.9; librss/remnants</String>
<Description>Akregator news feed reader for KDE</Description>
<Type>B</Type>
<Comment/>
<Link1>http://akregator.kde.org/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_37</ID>
<String>Aladin/3.324</String>
<Description>Aladin robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aladin.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_180408_1</ID>
<String>Alcatel-BG3/1.0 UP.Browser/5.0.3.1.2</String>
<Description>Phone.com UP.Browser for mobiles on Alcatel cellphone</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.openwave.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_38</ID>
<String>Aleksika Spider/1.0 (+http://www.aleksika.com/)</String>
<Description>Aleksika Danmark - Search engine optimization spider</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.aleksika.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_291108_2</ID>
<String>AlertInfo 2.0 (Powered by Newsbrain)</String>
<Description>Alertinfo - French version of Feedreader 3.xx </Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.feedreader.com/</Link1>
<Link2>http://www.geste.fr/alertinfo/home.html</Link2>
</user-agent>
<user-agent>
<ID>id_a_f_39</ID>
<String>AlkalineBOT/1.3</String>
<Description>Vestris robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://alkaline.vestris.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_40</ID>
<String>AlkalineBOT/1.4 (1.4.0326.0 RTM)</String>
<Description>Vestris robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://alkaline.vestris.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_41</ID>
<String>Allesklar/0.1 libwww-perl/5.46</String>
<Description>Allesklar.de robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.allesklar.de</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_42</ID>
<String>Alligator 1.31 (www.nearsoftware.com)</String>
<Description>Alligator download manager</Description>
<Type>D</Type>
<Comment/>
<Link1>http://www.nearsoftware.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_011108_1</ID>
<String>Allrati/1.1 (+)</String>
<Description>Unknown robot from Allrati.com</Description>
<Type>R</Type>
<Comment>67.205.96.xxx/67.205.104.xx</Comment>
<Link1>http://www.allrati.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_43</ID>
<String>AltaVista Intranet V2.0 AVS EVAL search@freeit.com</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_44</ID>
<String>AltaVista Intranet V2.0 Compaq Altavista Eval sveand@altavista.net</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_45</ID>
<String>AltaVista Intranet V2.0 evreka.com crawler@evreka.com</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_46</ID>
<String>AltaVista V2.0B crawler@evreka.com</String>
<Description>Altavista robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.altavista.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_280209_1</ID>
<String>amaya/x.xx libwww/x.x.x</String>
<Description>Amaya - W3C's Editor/Browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.w3.org/Amaya/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_47</ID>
<String>AmfibiBOT</String>
<Description>Amfibi Search robot</Description>
<Type>R</Type>
<Comment>64.111.217.9x</Comment>
<Link1>http://www.amfibi.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_48</ID>
<String>Amfibibot/0.06 (Amfibi Web Search; http://www.amfibi.com; agent@amfibi.com)</String>
<Description>Amfibi Search robot</Description>
<Type>R</Type>
<Comment>64.111.217.9x</Comment>
<Link1>http://www.amfibi.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_141105_2</ID>
<String>Amfibibot/0.07 (Amfibi Robot; http://www.amfibi.com; agent@amfibi.com)</String>
<Description>Amfibi Search robot</Description>
<Type>R</Type>
<Comment>64.111.217.9x</Comment>
<Link1>http://www.amfibi.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_49</ID>
<String>amibot</String>
<Description>amibot - Amidalla search engine robot (62.241.33.xx)</Description>
<Type>R</Type>
<Comment>s. also libwww-perl/5.65</Comment>
<Link1>http://www.amidalla.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_50</ID>
<String>Amiga-AWeb/3.4.167SE</String>
<Description>AWeb Amiga browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.amitrix.com/aweb.html</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_51</ID>
<String>AmigaVoyager/3.4.4 (MorphOS/PPC native)</String>
<Description>Voyager - Amiga browser</Description>
<Type>B</Type>
<Comment/>
<Link1>http://www.vapor.com/voyager/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_091205_1</ID>
<String>AmiTCP Miami (AmigaOS 2.04)</String>
<Description>Amiga Miami TCP Stack</Description>
<Type/>
<Comment/>
<Link1>http://home.ptd.net/~strdustr/amirc/Netware.html</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_210608_1</ID>
<String>Amoi 8512/R21.0 NF-Browser/3.3</String>
<Description>NF embedded browser on Amois Skypephone</Description>
<Type>B</Type>
<Comment/>
<Link1>http://3skypephone.com/</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_190206_3</ID>
<String>amzn_assoc</String>
<Description>Amazon.com robot for checking their affiliate sites</Description>
<Type>C</Type>
<Comment>s. also aranhabot</Comment>
<Link1/>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_52</ID>
<String>AnnoMille spider 0.1 alpha - http://www.annomille.it</String>
<Description>Annomille Italian historical oriented robot</Description>
<Type>R</Type>
<Comment/>
<Link1>http://www.annomille.it</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_53</ID>
<String>annotate_google; http://ponderer.org/download/annotate_google.user.js</String>
<Description>annotate Google - Firefox extension for annotating Google search results</Description>
<Type>B</Type>
<Comment/>
<Link1>http://ponderer.org/annotate_google</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_54</ID>
<String>Anonymized by ProxyOS: http://www.megaproxy.com</String>
<Description>Megaproxy user</Description>
<Type>P</Type>
<Comment/>
<Link1>http://www.megaproxy.com</Link1>
<Link2/>
</user-agent>
<user-agent>
<ID>id_a_f_55</ID>
<String>Anonymizer/1.1</String>
<Description>faked user agent</Description>
<Type/>
<Comment/>
<Link1/>
<Link2/>
</user-agent>
</user-agents>
''')

etree = ET.parse(xml_data) #create an ElementTree object 
doc_df = pd.DataFrame(list(iter_docs(etree.getroot())))

# %%
doc_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io

def iter_docs(author):
    author_attr = author.attrib
    for doc in author.iter('document'):
        doc_dict = author_attr.copy()
        doc_dict.update(doc.attrib)
        doc_dict['data'] = doc.text
        yield doc_dict

xml_data = io.StringIO('''\
<author type="XXX" language="EN" gender="xx" feature="xx" web="foobar.com">
    <documents count="N">
        <document KEY="e95a9a6c790ecb95e46cf15bee517651" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...]
]]>
        </document>
        <document KEY="bc360cfbafc39970587547215162f0db" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...]
]]>
        </document>
        <document KEY="19e71144c50a8b9160b3f0955e906fce" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...]
]]>
        </document>
        <document KEY="21d4af9021a174f61b884606c74d9e42" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...]
]]>
        </document>
        <document KEY="28a45eb2460899763d709ca00ddbb665" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...]
]]>
        </document>
        <document KEY="a0c0712a6a351f85d9f5757e9fff8946" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...]
]]>
        </document>
        <document KEY="626726ba8d34d15d02b6d043c55fe691" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...]
]]>
        </document>
        <document KEY="2cb473e0f102e2e4a40aa3006e412ae4" web="www.foo_bar_exmaple.com"><![CDATA[A large text with lots of strings and punctuations symbols [...] [...]
]]>
        </document>
    </documents>
</author>
''')

etree = ET.parse(xml_data) #create an ElementTree object 
doc_df = pd.DataFrame(list(iter_docs(etree.getroot())))

# %%
doc_df
# Out:
#                                 KEY  \
# 0  e95a9a6c790ecb95e46cf15bee517651
# 1  bc360cfbafc39970587547215162f0db
# 2  19e71144c50a8b9160b3f0955e906fce
# 3  21d4af9021a174f61b884606c74d9e42
# 4  28a45eb2460899763d709ca00ddbb665
# 5  a0c0712a6a351f85d9f5757e9fff8946
# 6  626726ba8d34d15d02b6d043c55fe691
# 7  2cb473e0f102e2e4a40aa3006e412ae4
#
#                                                 data feature gender language  \
# 0  A large text with lots of strings and punctuat...      xx     xx       EN
# 1  A large text with lots of strings and punctuat...      xx     xx       EN
# 2  A large text with lots of strings and punctuat...      xx     xx       EN
# 3  A large text with lots of strings and punctuat...      xx     xx       EN
# 4  A large text with lots of strings and punctuat...      xx     xx       EN
# 5  A large text with lots of strings and punctuat...      xx     xx       EN
# 6  A large text with lots of strings and punctuat...      xx     xx       EN
# 7  A large text with lots of strings and punctuat...      xx     xx       EN
#
#   type                      web
# 0  XXX  www.foo_bar_exmaple.com
# 1  XXX  www.foo_bar_exmaple.com
# 2  XXX  www.foo_bar_exmaple.com
# 3  XXX  www.foo_bar_exmaple.com
# 4  XXX  www.foo_bar_exmaple.com
# 5  XXX  www.foo_bar_exmaple.com
# 6  XXX  www.foo_bar_exmaple.com
# 7  XXX  www.foo_bar_exmaple.com

# %%
! pip install lxml
# Out:
# Collecting lxml
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/30/65/6dcc7a1a0ec3bbc10a1316b3610f9997ca132183a5f5345c5b88fc1eaf79/lxml-4.2.1-cp35-cp35m-manylinux1_x86_64.whl
# Installing collected packages: lxml
# Successfully installed lxml-4.2.1
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d367771bf6b1> in <module>()
#       1 path = '/home/abhi/Desktop/allagents.xml'
# ----> 2 xml = objectify.parse(open(path))
#
# NameError: name 'objectify' is not defined

# %%
path = '/home/abhi/Desktop/allagents.xml'
xml = objectify.parse(open(path))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d367771bf6b1> in <module>()
#       1 path = '/home/abhi/Desktop/allagents.xml'
# ----> 2 xml = objectify.parse(open(path))
#
# NameError: name 'objectify' is not defined

# %%
from lxml import objectify

# %%
import lxml
path = '/home/abhi/Desktop/allagents.xml'
xml = objectify.parse(open(path))
root = xml.getroot()

# %%
root
# Out:
# <Element user-agents at 0x7fe6a9003f48>

# %%
root.getchildren()[0].getchildren()
# Out:
# ['id_a_f_3',
#  '!Susie (http://www.sync2it.com/susie)',
#  'Sync2It bookmark management & clustering engine',
#  'C R',
#  '',
#  'http://www.sync2it.com',
#  '']

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
for i in range(0,4):
    obj = root.getchildren()[i].getchildren()
    row = dict(zip(['id', 'name'], [obj[0].text, obj[1].text]))
    row_s = pd.Series(row)
    row_s.name = i
    df = df.append(row_s)

# %%
df
# Out:
#          id                                               name
# 0  id_a_f_3              !Susie (http://www.sync2it.com/susie)
# 1  id_a_f_6  <a href='http://www.unchaos.com/'> UnChaos </a...
# 2  id_a_f_7  <a href='http://www.unchaos.com/'> UnChaos Bot...
# 3  id_a_f_8  <b> UnChaosBot From Chaos To Order UnChaos Hyb...

# %%
df2 = pd.DataFrame()

# %%
root.items()
# Out:
# []

# %%
ue = root.getchildren()[1500]

# %%
ue.values()
# Out:
# []

# %%
root.countchildren()
# Out:
# 2459

# %%
i=0
li1 = root.getchildren()[i].getchildren()
obj = li1
i=i+1
col_num = len(li1)
for i in range(root.countchildren()):
    row = dict(zip(range(len(obj)), [j.text for j in obj]))
    row_s = pd.Series(row)
    row_s.name = i
    df5 = df5.append(row_s)
    obj = root.getchildren()[i].getchildren()

# %%
df5 = pd.DataFrame()

# %%
df5
# Out:
#                     0                                                  1  \
# 0            id_a_f_3              !Susie (http://www.sync2it.com/susie)
# 1            id_a_f_3              !Susie (http://www.sync2it.com/susie)
# 2            id_a_f_6  <a href='http://www.unchaos.com/'> UnChaos </a...
# 3            id_a_f_7  <a href='http://www.unchaos.com/'> UnChaos Bot...
# 4            id_a_f_8  <b> UnChaosBot From Chaos To Order UnChaos Hyb...
# 5            id_a_f_9       <http://www.sygol.com/> http://www.sygol.com
# 6            id_a_f_4  ( Robots.txt Validator http://www.searchengine...
# 7     id_a_f_171105_1               (DreamPassport/3.0; isao/MyDiGiRabi)
# 8     id_a_f_290606_1                                      (Privoxy/1.0)
# 9     id_a_f_230507_1                                    */Nutch-0.9-dev
# 10           id_a_f_5         +SitiDi.net/SitiDiBot/1.0 (+Have Good Day)
# 11           id_a_f_1  -DIE-KRAEHE- META-SEARCH-ENGINE/1.1 http://www...
# 12    id_a_f_060206_1  123spider-Bot (Version: 1.02, powered by www.1...
# 13    id_a_f_180806_1                                       192.comAgent
# 14    id_a_f_060606_1  1st ZipCommander (Net) - http://www.zipcommand...
# 15          id_a_f_10             2Bone_LinkChecker/1.0 libwww-perl/5.64
# 16          id_a_f_11                     4anything.com LinkChecker v2.0
# 17    id_a_f_110207_1                          8484 Boston Project v 1.0
# 18           id_a_f_2  :robot/1.0 (linux) ( admin e-mail: undefined h...
# 19          id_a_f_12                                    A-Online Search
# 20    id_a_f_090707_1  A1 Keyword Research/1.0.2 (+http://www.micro-s...
# 21    id_a_f_100906_1  A1 Sitemap Generator/1.0 (+http://www.micro-sy...
# 22    id_a_f_250408_2                                   aardvark-crawler
# 23          id_a_f_13                                          AbachoBOT
# 24          id_a_f_14                     AbachoBOT (Mozilla compatible)
# 25          id_a_f_15                      ABCdatos BotLink/5.xx.xxx#BBL
# 26          id_a_f_16                                   Aberja Checkomat
# 27          id_a_f_17  abot/0.1 (abot; http://www.abot.com; abot@abot...
# 28          id_a_f_18                          About/0.1libwww-perl/5.47
# 29    id_a_f_051206_3                          Accelatech RSSCrawler/0.4
# ...               ...                                                ...
# 2429  id_t_z_210106_3                               yoogliFetchAgent/0.1
# 2430  id_t_z_120606_1                          yoono/1.0 web-crawler/1.0
# 2431      id_t_z_1533  YottaCars_Bot/4.12 (+http://www.yottacars.com)...
# 2432      id_t_z_1534  YottaShopping_Bot/4.12 (+http://www.yottashopp...
# 2433      id_t_z_1535                                         YTunnelPro
# 2434      id_t_z_1536  Z-Add Link Checker (http://w3.z-add.co.uk/link...
# 2435      id_t_z_1537                                        Zao-Crawler
# 2436      id_t_z_1538                                   Zao-Crawler 0.2b
# 2437      id_t_z_1539              Zao/0.1 (http://www.kototoi.org/zao/)
# 2438      id_t_z_1540                    ZBot/1.00 (icaulfield@zeus.com)
# 2439  id_t_z_111205_5                                           Zearchit
# 2440  id_t_z_130106_2                        ZeBot_lseek.net (bot@ze.bz)
# 2441      id_t_z_1541                ZeBot_www.ze.bz (ze.bz@hotmail.com)
# 2442  id_t_z_130806_2           zedzo.digest/0.1 (http://www.zedzo.com/)
# 2443  id_t_z_210807_2                                   Zend_Http_Client
# 2444  id_t_z_290208_2  zermelo Mozilla/5.0 compatible; heritrix/1.12....
# 2445      id_t_z_1542               zerxbot/Version 0.6 libwww-perl/5.79
# 2446      id_t_z_1543       Zeus ThemeSite Viewer Webster Pro V2.9 Win32
# 2447      id_t_z_1544                  Zeus xxxxx Webster Pro V2.9 Win32
# 2448  id_t_z_281105_1  Zeusbot/0.07 (Ulysseek's web-crawling robot; h...
# 2449      id_t_z_1545                     Ziggy -- The Clown From Hell!!
# 2450      id_t_z_1546  ZipppBot/0.xx (ZipppBot; http://www.zippp.net;...
# 2451      id_t_z_1547  ZIPPPCVS/0.xx (ZipppBot/.xx;http://www.zippp.n...
# 2452      id_t_z_1548                       Zippy v2.0 - Zippyfinder.com
# 2453      id_t_z_1549    Zoo Tycoon 2 Client -- http://www.zootycoon.com
# 2454      id_t_z_1550                          ZoomSpider - wrensoft.com
# 2455  id_t_z_160110_1  Zscho.de Crawler/Nutch-1.0-Zscho.de-semantic_p...
# 2456  id_t_z_280306_1    zspider/0.9-dev http://feedback.redkolibri.com/
# 2457      id_t_z_1551  ZyBorg/1.0 (ZyBorg@WISEnut.com; http://www.WIS...
# 2458  id_new_190610_1  Mozilla/5.0 (Windows; U; Windows NT 5.1; de; r...
#
#                                                       2  \
# 0       Sync2It bookmark management & clustering engine
# 1       Sync2It bookmark management & clustering engine
# 2                                  UnCHAOS search robot
# 3                                  UnCHAOS search robot
# 4                                  UnCHAOS search robot
# 5                            Sygol Search (Italy) robot
# 6              SearchEngineWorld's robots.txt validator
# 7                       DreamCast DreamPassport browser
# 8                                     Privoxy web proxy
# 9                                   Unknown Yahoo robot
# 10                    SitiDi.net search (Germany) robot
# 11    Die Kraehe Meta-Search-Engine (Germany) link c...
# 12    123spider.de (Germany) web directory link chec...
# 13                           192.com - UK web directory
# 14              1st ZipCommander Net - IE based browser
# 15                            2Bone online link checker
# 16                                      4Anything robot
# 17    Unknown guestbook spamming or harvesting tool ...
# 18                        neofonie search robot Germany
# 19               A-Online.at robot - now Jet2Web Search
# 20    A1 Keyword Research - search engine and keywor...
# 21    MiggiBot website crawler engine - A1 Sitemap G...
# 22    Aardvark web crawler for Sun's Blog recommenda...
# 23                            Abacho / Crawler.de robot
# 24                            Abacho / Crawler.de robot
# 25    ABCdatos - Castilian program & tutorial directory
# 26    Aberja Hybridsuchmaschine (Germany) link checking
# 27    Nameprotect copyright search robot (24.177.134.x)
# 28                                          About robot
# 29                   Accela Technology RSS feed crawler
# ...                                                 ...
# 2429            Yoogli search (under development) agent
# 2430  Yoono - community based search (193.110.140.xx...
# 2431  YottaCars bot - YottaCar car search engine ( 6...
# 2432  YottaShopping bot - YottaShopping search engin...
# 2433  Y!TunnelPro - Yahoo! Messenger companion user ...
# 2434                          Z-Add online link checker
# 2435                    Zao crawler for Kototoi Project
# 2436                    Zao crawler for Kototoi Project
# 2437                    Zao crawler for Kototoi Project
# 2438  Zeus Internet Marketing Robot based on Webster...
# 2439                 Zearchit German search / directory
# 2440                    Ze.bz Moteur de Recherche robot
# 2441                    Ze.bz Moteur de Recherche robot
# 2442                          ZedZo Search (beta) robot
# 2443     Zend PHP frameworks Zend_Http_Client component
# 2444  Powerset Natural Language Search crawler (unde...
# 2445                                Zerx search robot ?
# 2446  Zeus Internet Marketing Robot (based on Webste...
# 2447  Zeus Internet Marketing Robot (based on Webste...
# 2448  Zeusbot robot for building the Ulsysseek.com i...
# 2449  Unknown agent (server- or link checking ?) fro...
# 2450                          Zipp.net web search robot
# 2451                          Zipp.net web search robot
# 2452                                  Zippyfinder robot
# 2453                 Microsoft Zoo Tycoon 2 game client
# 2454                 Zoom Search Engine software spider
# 2455   collecting for machine learning; http://zscho...
# 2456              zspider robot for a new search engine
# 2457                                      Wisenut robot
# 2458                   FM Scene soccer fan pages plugin
#
#                                    3  \
# 0                                C R
# 1                                C R
# 2                                  R
# 3                                  R
# 4                                  R
# 5                                  R
# 6                                  C
# 7                                  B
# 8                                  P
# 9                                  R
# 10                                 R
# 11                                 R
# 12                                 C
# 13                                 R
# 14                                 B
# 15                                 C
# 16                                 R
# 17                                 S
# 18                                 R
# 19                                 R
# 20                                 C
# 21                                 R
# 22                                 R
# 23                                 R
# 24                                 R
# 25                                 R
# 26                                 R
# 27                                 R
# 28                                 R
# 29                                 R
# ...                              ...
# 2429                               R
# 2430                               R
# 2431                               R
# 2432                               R
# 2433                               B
# 2434                               C
# 2435                               R
# 2436                               R
# 2437                               R
# 2438                               R
# 2439                               R
# 2440                               R
# 2441                               R
# 2442                               R
# 2443                               D
# 2444                               R
# 2445                               R
# 2446                               R
# 2447                               R
# 2448                               R
# 2449                               C
# 2450                               R
# 2451                               R
# 2452                               R
# 2453                               B
# 2454                               R
# 2455  Zscho search crawler (Germany)
# 2456                               R
# 2457                               R
# 2458                               L
#
#                                                       4  \
# 0                                                  None
# 1                                                  None
# 2                                          Site is dead
# 3                                          Site is dead
# 4                                          Site is dead
# 5                                       s.also SygolBot
# 6                         Services is no more available
# 7                                                  None
# 8                        s.also Privoxy/3.0 (Anonymous)
# 9                                       123.113.184.2xx
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                       217.160.75.2xx
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                           s. various honey pot sites
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                          192.9.71.7x
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27    s. also - np/0.1_(np;_http://www.nameprotect.c...
# 28                                                 None
# 29                                      125.100.242.2xx
# ...                                                 ...
# 2429                                               None
# 2430  s. also Mozilla/5.0 (compatible; Yoono; http:/...
# 2431                           s. also OmniExplorer_Bot
# 2432                           s. also OmniExplorer_Bot
# 2433                                     s. Y!TunnelPro
# 2434                                               None
# 2435                                               None
# 2436                                               None
# 2437                                               None
# 2438                                               None
# 2439                                    212.227.109.1xx
# 2440                                     213.251.135.xx
# 2441                                     213.251.135.xx
# 2442                                       24.62.50.1xx
# 2443                                               None
# 2444                                      67.202.34.xxx
# 2445                                     138.88.147.xxx
# 2446                                               None
# 2447                                               None
# 2448                                   powered by Nutch
# 2449                                               None
# 2450                                               None
# 2451                                               None
# 2452                                               None
# 2453                                               None
# 2454                                               None
# 2455                                                  R
# 2456                                               None
# 2457                                               None
# 2458                                               None
#
#                                                       5  \
# 0                                http://www.sync2it.com
# 1                                http://www.sync2it.com
# 2                               http://www.unchaos.com/
# 3                               http://www.unchaos.com/
# 4                               http://www.unchaos.com/
# 5                                 http://www.sygol.com/
# 6     http://www.searchengineworld.com/cgi-bin/robot...
# 7                             http://www.dricas.com/dp/
# 8                               http://www.privoxy.org/
# 9                                  http://www.yahoo.com
# 10                               http://www.sitidi.net/
# 11                             http://www.die-kraehe.de
# 12                             http://www.123spider.de/
# 13                                  http://www.192.com/
# 14                         http://www.zipcommander.com/
# 15         http://www.2bone.com/links/linkchecker.shtml
# 16                             http://www.4anything.com
# 17    http://www.projecthoneypot.org/bsh_X19tb2RlPWd...
# 18             http://www.neofonie.de/loesungen/search/
# 19                        http://www.jet2web.net/portal
# 20    http://www.micro-sys.dk/products/keyword-resea...
# 21    http://www.micro-sys.dk/products/sitemap-gener...
# 22                        http://blogs.sun.com/plamere/
# 23                                http://www.abacho.com
# 24                                http://www.abacho.com
# 25                              http://www.abcdatos.com
# 26                                 http://www.aberja.de
# 27                          http://www.nameprotect.com/
# 28                                 http://www.about.com
# 29                           http://www.accelatech.com/
# ...                                                 ...
# 2429                             http://www.yoogli.com/
# 2430                              http://www.yoono.com/
# 2431                          http://www.yottacars.com/
# 2432                      http://www.yottashopping.com/
# 2433                         http://www.ytunnelpro.com/
# 2434                   http://w3.z-add.co.uk/linkcheck/
# 2435                        http://www.kototoi.org/zao/
# 2436                        http://www.kototoi.org/zao/
# 2437                        http://www.kototoi.org/zao/
# 2438                         http://cyber-robotics.com/
# 2439                            http://www.zearchit.de/
# 2440                                  http://www.ze.bz/
# 2441                                  http://www.ze.bz/
# 2442                              http://www.zedzo.com/
# 2443  http://framework.zend.com/manual/en/zend.http....
# 2444                           http://www.powerset.com/
# 2445                               http://www.zerx.com/
# 2446                         http://cyber-robotics.com/
# 2447                         http://cyber-robotics.com/
# 2448                            http://www.zeusbot.com/
# 2449                                               None
# 2450                              http://www.zippp.net/
# 2451                              http://www.zippp.net/
# 2452                        http://www.zippyfinder.com/
# 2453                           http://www.zootycoon.com
# 2454                           http://www.wrensoft.com/
# 2455                                      141.65.161.xx
# 2456                    http://feedback.redkolibri.com/
# 2457                         http://www.wisenutbot.com/
# 2458                              http://www.fmscene.de
#
#                                                       6
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21          http://www.micro-sys.dk/developer/miggibot/
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 2429                                               None
# 2430                                               None
# 2431                                               None
# 2432                                               None
# 2433                                               None
# 2434                                               None
# 2435                                               None
# 2436                                               None
# 2437                                               None
# 2438                         http://www.homepagesw.com/
# 2439                                               None
# 2440                                               None
# 2441                                               None
# 2442                                               None
# 2443                                               None
# 2444  http://www.amazon.com/gp/browse.html?node=3435361
# 2445                                               None
# 2446                                               None
# 2447                                               None
# 2448                           http://www.ulysseek.com/
# 2449                                               None
# 2450                                               None
# 2451                                               None
# 2452                                               None
# 2453                                               None
# 2454                                               None
# 2455                               http://www.zscho.de/
# 2456                                               None
# 2457                                               None
# 2458                                               None
#
# [2459 rows x 7 columns]

# %%
type(ue)
# Out:
# lxml.objectify.ObjectifiedElement

# %%
ue = root.attrib

# %%
root.tag
# Out:
# 'user-agents'

# %%
ue0 = root.getchildren()[0].getchildren()

# %%
xml.getroot(
# Out:
#   File "<ipython-input-100-46603514a41d>", line 1
#     xml.getroot(
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
type(ue0)
# Out:
# lxml.objectify.ObjectifiedElement

# %%
ue0.tags
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-0cc19caa10e5> in <module>()
# ----> 1 ue0.tags
#
# AttributeError: 'list' object has no attribute 'tags'

# %%
df6 = pd.DataFrame()

# %%
import pandas as pd
from lxml import objectify

def xml_to_df(path,df_):
    xml = objectify.parse(open(path))
    root = xml.getroot()
    for i in range(root.countchildren()):
        obj = root.getchildren()[i].getchildren()
        row = dict(zip([j.tag for j in obj], [j.text for j in obj]))
        row_s = pd.Series(row)
        row_s.name = i
        df_ = df_.append(row_s)
    return df_

df_ = pd.DataFrame()
path = '/home/abhi/Desktop/allagents.xml'
df_=xml_to_df(path,df_)
print(df_.head())
# Out:
#            Comment                                      Description        ID  \
# 0             None  Sync2It bookmark management & clustering engine  id_a_f_3
# 1     Site is dead                             UnCHAOS search robot  id_a_f_6
# 2     Site is dead                             UnCHAOS search robot  id_a_f_7
# 3     Site is dead                             UnCHAOS search robot  id_a_f_8
# 4  s.also SygolBot                       Sygol Search (Italy) robot  id_a_f_9
#
#                      Link1 Link2  \
# 0   http://www.sync2it.com  None
# 1  http://www.unchaos.com/  None
# 2  http://www.unchaos.com/  None
# 3  http://www.unchaos.com/  None
# 4    http://www.sygol.com/  None
#
#                                               String Type
# 0              !Susie (http://www.sync2it.com/susie)  C R
# 1  <a href='http://www.unchaos.com/'> UnChaos </a...    R
# 2  <a href='http://www.unchaos.com/'> UnChaos Bot...    R
# 3  <b> UnChaosBot From Chaos To Order UnChaos Hyb...    R
# 4       <http://www.sygol.com/> http://www.sygol.com    R

# %%
df6
# Out:
#                                                 Comment  \
# 0                                                  None
# 1                                                  None
# 2                                          Site is dead
# 3                                          Site is dead
# 4                                          Site is dead
# 5                                       s.also SygolBot
# 6                         Services is no more available
# 7                                                  None
# 8                        s.also Privoxy/3.0 (Anonymous)
# 9                                       123.113.184.2xx
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                       217.160.75.2xx
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                           s. various honey pot sites
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                          192.9.71.7x
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27    s. also - np/0.1_(np;_http://www.nameprotect.c...
# 28                                                 None
# 29                                      125.100.242.2xx
# ...                                                 ...
# 2429                                               None
# 2430  s. also Mozilla/5.0 (compatible; Yoono; http:/...
# 2431                           s. also OmniExplorer_Bot
# 2432                           s. also OmniExplorer_Bot
# 2433                                     s. Y!TunnelPro
# 2434                                               None
# 2435                                               None
# 2436                                               None
# 2437                                               None
# 2438                                               None
# 2439                                    212.227.109.1xx
# 2440                                     213.251.135.xx
# 2441                                     213.251.135.xx
# 2442                                       24.62.50.1xx
# 2443                                               None
# 2444                                      67.202.34.xxx
# 2445                                     138.88.147.xxx
# 2446                                               None
# 2447                                               None
# 2448                                   powered by Nutch
# 2449                                               None
# 2450                                               None
# 2451                                               None
# 2452                                               None
# 2453                                               None
# 2454                                               None
# 2455                                                  R
# 2456                                               None
# 2457                                               None
# 2458                                               None
#
#                                             Description               ID  \
# 0       Sync2It bookmark management & clustering engine         id_a_f_3
# 1       Sync2It bookmark management & clustering engine         id_a_f_3
# 2                                  UnCHAOS search robot         id_a_f_6
# 3                                  UnCHAOS search robot         id_a_f_7
# 4                                  UnCHAOS search robot         id_a_f_8
# 5                            Sygol Search (Italy) robot         id_a_f_9
# 6              SearchEngineWorld's robots.txt validator         id_a_f_4
# 7                       DreamCast DreamPassport browser  id_a_f_171105_1
# 8                                     Privoxy web proxy  id_a_f_290606_1
# 9                                   Unknown Yahoo robot  id_a_f_230507_1
# 10                    SitiDi.net search (Germany) robot         id_a_f_5
# 11    Die Kraehe Meta-Search-Engine (Germany) link c...         id_a_f_1
# 12    123spider.de (Germany) web directory link chec...  id_a_f_060206_1
# 13                           192.com - UK web directory  id_a_f_180806_1
# 14              1st ZipCommander Net - IE based browser  id_a_f_060606_1
# 15                            2Bone online link checker        id_a_f_10
# 16                                      4Anything robot        id_a_f_11
# 17    Unknown guestbook spamming or harvesting tool ...  id_a_f_110207_1
# 18                        neofonie search robot Germany         id_a_f_2
# 19               A-Online.at robot - now Jet2Web Search        id_a_f_12
# 20    A1 Keyword Research - search engine and keywor...  id_a_f_090707_1
# 21    MiggiBot website crawler engine - A1 Sitemap G...  id_a_f_100906_1
# 22    Aardvark web crawler for Sun's Blog recommenda...  id_a_f_250408_2
# 23                            Abacho / Crawler.de robot        id_a_f_13
# 24                            Abacho / Crawler.de robot        id_a_f_14
# 25    ABCdatos - Castilian program & tutorial directory        id_a_f_15
# 26    Aberja Hybridsuchmaschine (Germany) link checking        id_a_f_16
# 27    Nameprotect copyright search robot (24.177.134.x)        id_a_f_17
# 28                                          About robot        id_a_f_18
# 29                   Accela Technology RSS feed crawler  id_a_f_051206_3
# ...                                                 ...              ...
# 2429            Yoogli search (under development) agent  id_t_z_210106_3
# 2430  Yoono - community based search (193.110.140.xx...  id_t_z_120606_1
# 2431  YottaCars bot - YottaCar car search engine ( 6...      id_t_z_1533
# 2432  YottaShopping bot - YottaShopping search engin...      id_t_z_1534
# 2433  Y!TunnelPro - Yahoo! Messenger companion user ...      id_t_z_1535
# 2434                          Z-Add online link checker      id_t_z_1536
# 2435                    Zao crawler for Kototoi Project      id_t_z_1537
# 2436                    Zao crawler for Kototoi Project      id_t_z_1538
# 2437                    Zao crawler for Kototoi Project      id_t_z_1539
# 2438  Zeus Internet Marketing Robot based on Webster...      id_t_z_1540
# 2439                 Zearchit German search / directory  id_t_z_111205_5
# 2440                    Ze.bz Moteur de Recherche robot  id_t_z_130106_2
# 2441                    Ze.bz Moteur de Recherche robot      id_t_z_1541
# 2442                          ZedZo Search (beta) robot  id_t_z_130806_2
# 2443     Zend PHP frameworks Zend_Http_Client component  id_t_z_210807_2
# 2444  Powerset Natural Language Search crawler (unde...  id_t_z_290208_2
# 2445                                Zerx search robot ?      id_t_z_1542
# 2446  Zeus Internet Marketing Robot (based on Webste...      id_t_z_1543
# 2447  Zeus Internet Marketing Robot (based on Webste...      id_t_z_1544
# 2448  Zeusbot robot for building the Ulsysseek.com i...  id_t_z_281105_1
# 2449  Unknown agent (server- or link checking ?) fro...      id_t_z_1545
# 2450                          Zipp.net web search robot      id_t_z_1546
# 2451                          Zipp.net web search robot      id_t_z_1547
# 2452                                  Zippyfinder robot      id_t_z_1548
# 2453                 Microsoft Zoo Tycoon 2 game client      id_t_z_1549
# 2454                 Zoom Search Engine software spider      id_t_z_1550
# 2455   collecting for machine learning; http://zscho...  id_t_z_160110_1
# 2456              zspider robot for a new search engine  id_t_z_280306_1
# 2457                                      Wisenut robot      id_t_z_1551
# 2458                   FM Scene soccer fan pages plugin  id_new_190610_1
#
#                                                   Link1  \
# 0                                http://www.sync2it.com
# 1                                http://www.sync2it.com
# 2                               http://www.unchaos.com/
# 3                               http://www.unchaos.com/
# 4                               http://www.unchaos.com/
# 5                                 http://www.sygol.com/
# 6     http://www.searchengineworld.com/cgi-bin/robot...
# 7                             http://www.dricas.com/dp/
# 8                               http://www.privoxy.org/
# 9                                  http://www.yahoo.com
# 10                               http://www.sitidi.net/
# 11                             http://www.die-kraehe.de
# 12                             http://www.123spider.de/
# 13                                  http://www.192.com/
# 14                         http://www.zipcommander.com/
# 15         http://www.2bone.com/links/linkchecker.shtml
# 16                             http://www.4anything.com
# 17    http://www.projecthoneypot.org/bsh_X19tb2RlPWd...
# 18             http://www.neofonie.de/loesungen/search/
# 19                        http://www.jet2web.net/portal
# 20    http://www.micro-sys.dk/products/keyword-resea...
# 21    http://www.micro-sys.dk/products/sitemap-gener...
# 22                        http://blogs.sun.com/plamere/
# 23                                http://www.abacho.com
# 24                                http://www.abacho.com
# 25                              http://www.abcdatos.com
# 26                                 http://www.aberja.de
# 27                          http://www.nameprotect.com/
# 28                                 http://www.about.com
# 29                           http://www.accelatech.com/
# ...                                                 ...
# 2429                             http://www.yoogli.com/
# 2430                              http://www.yoono.com/
# 2431                          http://www.yottacars.com/
# 2432                      http://www.yottashopping.com/
# 2433                         http://www.ytunnelpro.com/
# 2434                   http://w3.z-add.co.uk/linkcheck/
# 2435                        http://www.kototoi.org/zao/
# 2436                        http://www.kototoi.org/zao/
# 2437                        http://www.kototoi.org/zao/
# 2438                         http://cyber-robotics.com/
# 2439                            http://www.zearchit.de/
# 2440                                  http://www.ze.bz/
# 2441                                  http://www.ze.bz/
# 2442                              http://www.zedzo.com/
# 2443  http://framework.zend.com/manual/en/zend.http....
# 2444                           http://www.powerset.com/
# 2445                               http://www.zerx.com/
# 2446                         http://cyber-robotics.com/
# 2447                         http://cyber-robotics.com/
# 2448                            http://www.zeusbot.com/
# 2449                                               None
# 2450                              http://www.zippp.net/
# 2451                              http://www.zippp.net/
# 2452                        http://www.zippyfinder.com/
# 2453                           http://www.zootycoon.com
# 2454                           http://www.wrensoft.com/
# 2455                                      141.65.161.xx
# 2456                    http://feedback.redkolibri.com/
# 2457                         http://www.wisenutbot.com/
# 2458                              http://www.fmscene.de
#
#                                                   Link2  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21          http://www.micro-sys.dk/developer/miggibot/
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 2429                                               None
# 2430                                               None
# 2431                                               None
# 2432                                               None
# 2433                                               None
# 2434                                               None
# 2435                                               None
# 2436                                               None
# 2437                                               None
# 2438                         http://www.homepagesw.com/
# 2439                                               None
# 2440                                               None
# 2441                                               None
# 2442                                               None
# 2443                                               None
# 2444  http://www.amazon.com/gp/browse.html?node=3435361
# 2445                                               None
# 2446                                               None
# 2447                                               None
# 2448                           http://www.ulysseek.com/
# 2449                                               None
# 2450                                               None
# 2451                                               None
# 2452                                               None
# 2453                                               None
# 2454                                               None
# 2455                               http://www.zscho.de/
# 2456                                               None
# 2457                                               None
# 2458                                               None
#
#                                                  String  \
# 0                 !Susie (http://www.sync2it.com/susie)
# 1                 !Susie (http://www.sync2it.com/susie)
# 2     <a href='http://www.unchaos.com/'> UnChaos </a...
# 3     <a href='http://www.unchaos.com/'> UnChaos Bot...
# 4     <b> UnChaosBot From Chaos To Order UnChaos Hyb...
# 5          <http://www.sygol.com/> http://www.sygol.com
# 6     ( Robots.txt Validator http://www.searchengine...
# 7                  (DreamPassport/3.0; isao/MyDiGiRabi)
# 8                                         (Privoxy/1.0)
# 9                                       */Nutch-0.9-dev
# 10           +SitiDi.net/SitiDiBot/1.0 (+Have Good Day)
# 11    -DIE-KRAEHE- META-SEARCH-ENGINE/1.1 http://www...
# 12    123spider-Bot (Version: 1.02, powered by www.1...
# 13                                         192.comAgent
# 14    1st ZipCommander (Net) - http://www.zipcommand...
# 15               2Bone_LinkChecker/1.0 libwww-perl/5.64
# 16                       4anything.com LinkChecker v2.0
# 17                            8484 Boston Project v 1.0
# 18    :robot/1.0 (linux) ( admin e-mail: undefined h...
# 19                                      A-Online Search
# 20    A1 Keyword Research/1.0.2 (+http://www.micro-s...
# 21    A1 Sitemap Generator/1.0 (+http://www.micro-sy...
# 22                                     aardvark-crawler
# 23                                            AbachoBOT
# 24                       AbachoBOT (Mozilla compatible)
# 25                        ABCdatos BotLink/5.xx.xxx#BBL
# 26                                     Aberja Checkomat
# 27    abot/0.1 (abot; http://www.abot.com; abot@abot...
# 28                            About/0.1libwww-perl/5.47
# 29                            Accelatech RSSCrawler/0.4
# ...                                                 ...
# 2429                               yoogliFetchAgent/0.1
# 2430                          yoono/1.0 web-crawler/1.0
# 2431  YottaCars_Bot/4.12 (+http://www.yottacars.com)...
# 2432  YottaShopping_Bot/4.12 (+http://www.yottashopp...
# 2433                                         YTunnelPro
# 2434  Z-Add Link Checker (http://w3.z-add.co.uk/link...
# 2435                                        Zao-Crawler
# 2436                                   Zao-Crawler 0.2b
# 2437              Zao/0.1 (http://www.kototoi.org/zao/)
# 2438                    ZBot/1.00 (icaulfield@zeus.com)
# 2439                                           Zearchit
# 2440                        ZeBot_lseek.net (bot@ze.bz)
# 2441                ZeBot_www.ze.bz (ze.bz@hotmail.com)
# 2442           zedzo.digest/0.1 (http://www.zedzo.com/)
# 2443                                   Zend_Http_Client
# 2444  zermelo Mozilla/5.0 compatible; heritrix/1.12....
# 2445               zerxbot/Version 0.6 libwww-perl/5.79
# 2446       Zeus ThemeSite Viewer Webster Pro V2.9 Win32
# 2447                  Zeus xxxxx Webster Pro V2.9 Win32
# 2448  Zeusbot/0.07 (Ulysseek's web-crawling robot; h...
# 2449                     Ziggy -- The Clown From Hell!!
# 2450  ZipppBot/0.xx (ZipppBot; http://www.zippp.net;...
# 2451  ZIPPPCVS/0.xx (ZipppBot/.xx;http://www.zippp.n...
# 2452                       Zippy v2.0 - Zippyfinder.com
# 2453    Zoo Tycoon 2 Client -- http://www.zootycoon.com
# 2454                          ZoomSpider - wrensoft.com
# 2455  Zscho.de Crawler/Nutch-1.0-Zscho.de-semantic_p...
# 2456    zspider/0.9-dev http://feedback.redkolibri.com/
# 2457  ZyBorg/1.0 (ZyBorg@WISEnut.com; http://www.WIS...
# 2458  Mozilla/5.0 (Windows; U; Windows NT 5.1; de; r...
#
#                                 Type
# 0                                C R
# 1                                C R
# 2                                  R
# 3                                  R
# 4                                  R
# 5                                  R
# 6                                  C
# 7                                  B
# 8                                  P
# 9                                  R
# 10                                 R
# 11                                 R
# 12                                 C
# 13                                 R
# 14                                 B
# 15                                 C
# 16                                 R
# 17                                 S
# 18                                 R
# 19                                 R
# 20                                 C
# 21                                 R
# 22                                 R
# 23                                 R
# 24                                 R
# 25                                 R
# 26                                 R
# 27                                 R
# 28                                 R
# 29                                 R
# ...                              ...
# 2429                               R
# 2430                               R
# 2431                               R
# 2432                               R
# 2433                               B
# 2434                               C
# 2435                               R
# 2436                               R
# 2437                               R
# 2438                               R
# 2439                               R
# 2440                               R
# 2441                               R
# 2442                               R
# 2443                               D
# 2444                               R
# 2445                               R
# 2446                               R
# 2447                               R
# 2448                               R
# 2449                               C
# 2450                               R
# 2451                               R
# 2452                               R
# 2453                               B
# 2454                               R
# 2455  Zscho search crawler (Germany)
# 2456                               R
# 2457                               R
# 2458                               L
#
# [2459 rows x 7 columns]
